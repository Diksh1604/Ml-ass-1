# %% [markdown]
# # **Ans 1:-**
# A parameter is a  variable that is used to define a particular characteristic in a system, function or fnction. It helps determine, specific meaning of "parameter" can vary depending on the context.
#
# **Eg:**
# In mathematics and statistics: A parameter is constant which defines a specific system or function. For example, in the equation of a line
# 𝑦
# =
# 𝑚
# 𝑥
# +
# 𝑏
# y=mx+b,
# here m and
# 𝑏
#  are parameters that define the slope and y-intercept of the line.

# %% [markdown]
# # **Ans 2:-**
#
# **Correlation** is a statistical term which describes relationship between 2 or more variables. It helps to measures how changes one variable which are associated with changes in another.
#
# **Negative correlation** is a relationship where one variable increases other decreases or it becomes vice versa. **bold text**

# %% [markdown]
# # **Ans 3:-**
#
# Machine Learning is subset of artificial intelligence which enables computers to learn from data and improve performance on tasks over time, without being explicitly programmed.
#
# ## **Main Components of Machine Learning are :-**
#
# **Training Process:**
# During training algorithm learns from the data by adjusting its internal parameters.
#
# It Involves techniques like gradient descent or other optimization methods.
#
# **Model Deployment:**
# After completing training, the model is deployed into production, which can make predictions on new and unseen data. This is where the model provide real value in real-world such as detecting fraud.

# %% [markdown]
# # **Ans 4:-**
# The loss value is a crucial indicator in machine learning that helps to determine how poorly a model is performing. It says difference between the model predictions and the true values. A higher loss value suggests the model predictions are far from the actual results.

# %% [markdown]
# # **Ans 5:-**
#
# ### **Continuous Variables:**
# **Definition:**
# Continuous variables are quantitative variables which can take any value within a given range. which are measurable and can have  infinite number of values between any two points.
# ### **Examples: **
# Age and distance.
#
# ### **Categorical Variables:**
# ### **Definition: **
# Categorical variables, also known as qualitative variables which represent categories. They describe qualities or characteristics that can be placed into distinct categories.
#
# **Examples:**
# Gender (male, female), nationality (American, Canadian, French).

# %% [markdown]
# # **Ans 6:-**
#
# Handling categorical variables is an essential in machine learning because most algorithms needs numerical inputs.
#
# Here are some examples of Common Techniques use for handle categorical data:-
#
# **One-Hot Encoding**
#
# Description: It creates new binary columns for each category.
#
# **Target Encoding**
#
# Description: It encodes categories based on the mean of the target variable for each category.

# %% [markdown]
# # **Ans 7:-**
#
# **Training Dataset**
#
#  The training dataset  used to train the machine learning model. This means that the model learns patterns, relationships, and features in the data that help it make predictions.
#
# **Testing a Dataset**
#
# The model has been trained, it tested on a different subset of the data called the test set. It checks how accurately the model can make predictions on data that it has seen during training.
#
# ### **Differences Between Training and Testing:**
#
# Training is teaching the model using the training data where testing is evaluating the model's performance on unused data.
# Training dataset helps the model to learn and the test dataset helps to check model's to generalize.

# %% [markdown]
# # **Ans 8:-**
#
# ### ***sklearn.preprocessing ***
#
# It is a module in the scikit-learn library it provides various utilities for transforming data before apply Machine Learning (ML) algorithm. Contain different classes and functions to normalize data.

# %% [markdown]
# # **Ans 9:-**
#
# ### **Test set**
#
# It is a subset of dataset used to evaluate the performance of machine learning model after it is trained and ready to use. It key components in the process of building, training, and validating machine learning models.

# %% [markdown]
# # **Ans 10:-**
#
# When approaching a machine learning (ML), splitting the data for model training and testing is one of steps in this process.
#
# 1) Data Preprocessing
#
# 2) Model Evaluation
#
# 3) Model Tuning
#
# 4) Deployment and Monitoring

# %% [markdown]
# # **Ans 11:-**
#
# Exploratory Data Analysis it is a essential step before fitting a machine learning model to data which helps you understand your dataset,  identify potential issues and make decisions on how to preprocess and model the data.

# %% [markdown]
# # **Ans 12:-**
#
# Correlation means quantifies how closely 2 variables move in relation with each other.

# %% [markdown]
# # **Ans 13:-**
#
# Negative correlation means one variable increases where other decrease. It specify an inverse relationship between variables. It helps in interpreting the nature of relationships in data.

# %% [markdown]
# # **Ans 15:-**
#
# Causation refers to relationship between phenomena where one event directly influences the occurrence of the other effect. This relationship is often tested through research that establish a direct link between cause and effect.
#
# ### **Difference Between Correlation and Causation**
#
# **Correlation:**
#
# Correlation is a statistical relationship between variables where tend vary together.
#
# **Example:**
#
#  Ice cream sales and the number of people who go swimming. Both tend to increase during the summer months. However, this does not mean that eating ice cream causes people to go swimming or vice versa. The underlying factor is likely the warm weather, which drives both behaviors.
#
# **Caustion:**
#
# It says that one event or variable directly causes another to happen.
#
# **Example:-**
#
# Drinking too much alcohol can cause serious health issues.

# %% [markdown]
# # **Ans 16:-**
#
# Optimizer is an algorithm which is used to minimize or maximize a function with adjusting the values of there parameters.
#
# ### **Types of Optimizer:**
#
# **1)Adam:** Combines momentum and adaptive learning rates.
#
# **Example:-** Go-to optimizer for modern architectures.
#
#
#
# **2)Mini-batch SGD:** Compromise used in practice.
#
# **Example:-** If you have a dataset with 1,000 samples, a mini-batch size of 100 would result in 10 updates per iterate commonly used in deep learning.
#
# **3)Nesterov:** Improved version of momentum.
#
# **Example:-** Advanced optimization tasks where quick convergence is needed, like training recurrent neural networks.
#
# **4)Stochastic Gradient Descent:**  Updates the parameters using a particular example.
#
# **Example:-** Computing the gradient for all training samples, computes the gradient for randomly chosen training sample and updates the weights accordingly.
#
# **5)Gradient Descent:** Basic and works well with few datasets.
#
# **Example:-** Gradient descent will update the weights and biases by parameters.
#
# **6)Momentum:** Helps in accelerate convergence.
#
# **Examples:-** Optimization path is oscillating or stuck in a shallow region, the momentum term helps to push the updates in a consistent direction.
#
# **7)RMSprop:** Stabilizes gradient descent.
#
# **8)Adagrad:** Learning rate of each parameter.

# %% [markdown]
# # **Ans 17:-**
#
# **sklearn.linear_model** it is a module in the scikit-learn library, it provides a collection of linear models for machine learning tasks. These models are primarily used for classification and dimensionality reduction. Linear model are a linear relationship.

# %% [markdown]
# # **Ans 18:-**
#
# **model.fit()** method in scikit-learn used to train machine learning model on a given dataset.
#
# **Arguments Required fit()**:
#
# 1)X: The input data
#
# 2)batch_size
#
# 3)callbacks
#
# 4)epochs

# %% [markdown]
# # **Ans 19:-**
#
# **Model.predict()** is used to make predictions with trained model after it has been trained using model.fit().
#
# **Arguments Required fit():**
#
# verbose

# %% [markdown]
# # **Ans 20:-**
#
# **Continuous Variables:-** It represent data which can take any value within a certain range.
#
# **Categorical Variables:-**
# Categorical variables is also called qualitative variables it represent data fall into distinct. These variables typically used to classify data into labels.

# %% [markdown]
# # **Ans 21:-**
#
# Feature scaling is the process of transforming the features of dataset into a similar scale or range, it ensures that no single feature dominates to learning process, otherwise negative affect performance of machine learning algorithms.
#
#  **Helps to feature scaling in Machine Learning:**
#
#  1) Avoids Dominance in Distance-Based Models
#  2) Improves Convergence in Gradient-Based Algorithms
#  3) Improves Performance in Regularization
#  4) Ensures Equal Contribution of Features

# %% [markdown]
# # ***Ans 22:- ***
#
# ### **Steps to Perform Feature Scaling in Python:**
#
# **Step 1:-**
#
# **Import Necessary Libraries:** You should import scikit-learn's scaling classes like StandardScaler, etc.
#
# **Step 2:-**
#
# **Choose a Scaling Method:** Based on data and machine learning algorithm, choose right scaling method. Common methods are:
#
# a)Z-score scaling
#
# b)Robust Scaling
#
# **Step 3:-**
#
# ***Fit and Transform the Data: ***
#
# Once done then select scaling method, then fit the scaler to your data and transform data as per yours needs.

# %% [markdown]
# # **Ans 23:-**
#
# What is sklearn.preprocessing?
#
# This question is repeated as this question and answer is same as 8th question.

# %% [markdown]
# # **Ans 24:-**
#
# **Steps to Split Data for Model Fitting:**
#
# ### **Step 1:-**
#
# Import Necessary Libraries
#
# ### **Step2**:-
# Prepare Your Dataset
#
# ### **Step 3:-**
#
# Split the Data

# %% [markdown]
# # **Ans 25:-**
#
# Data encoding is the process of converting categorical data into a numeric format in which that machine learning algorithms we can use.
